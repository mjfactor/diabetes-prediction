# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
for label in df.columns[:-1]:
    plt.hist(df[df["Outcome"]==0][label], bins=10, alpha=0.5, label="No Diabetes", color='Green')
    plt.hist(df[df["Outcome"]==1][label], bins=10, alpha=0.5, label="Diabetes", color='red' )
    plt.legend(loc='upper right')
    plt.title(label)
    plt.show()
